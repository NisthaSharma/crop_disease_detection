# %%
import tflite_runtime.interpreter as tflite

#Convert to tflite

# %%
model = tflite.Interpreter("model.tflite")

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("saved_models/2")

#Implement optimization strategy for smaller model sizes
#converter.optimizations = [tf.lite.Optimize.DEFAULT] #Uses default optimization strategy to reduce the model size
tflite_model = converter.convert()
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
with open('model.tflite','wb') as f:
    f.write(tflite_model)

# %%
import tflite_runtime.interpreter as tflite

model = tflite.Interpreter("model.tflite")

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Nistha Sharma\anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# WARNING:astropy:AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa"
# C:\Users\Nistha Sharma\anaconda3\lib\pkgutil.py:93: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\Users\Nistha Sharma\anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# b'\\\x00C\x00o\x00m\x00m\x00o\x00n\x00 \x00w\x00a\x00s\x00 \x00u\x00n\x00e\x00x\x00p\x00e\x00c\x00t\x00e\x00d\x00 \x00a\x00t\x00 \x00t\x00h\x00i\x00s\x00 \x00t\x00i\x00m\x00e\x00.\x00\r\x00\n\x00'
# Update LANGUAGE_CODES (inside config/base.py) if a new translation has been added to Spyder
# WARNING:qdarkstyle:No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# C:\Users\Nistha Sharma\anaconda3\lib\pkgutil.py:108: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              colorama            more_itertools      sortedcontainers
# IPython             colorsys            mpmath              soupsieve
# OpenSSL             commctrl            msgpack             sphinx
# PIL                 compileall          msilib              sphinxcontrib
# PyQt5               comtypes            msvcrt              spyder
# TBB                 concurrent          multipledispatch    spyder_kernels
# __future__          conda               multiprocessing     sqlalchemy
# _abc                conda_build         munkres             sqlite3
# _aix_support        conda_content_trust mypy_extensions     sre_compile
# _ast                conda_env           nacl                sre_constants
# _asyncio            conda_pack          navigator_updater   sre_parse
# _bisect             conda_package_handling nbclassic           ssl
# _black_version      conda_token         nbclient            sspi
# _blake2             conda_verify        nbconvert           sspicon
# _bootlocale         configparser        nbformat            stat
# _bootsubprocess     contextlib          nest_asyncio        statistics
# _bz2                contextlib2         netbios             statsmodels
# _cffi_backend       contextvars         netrc               storemagic
# _codecs             cookiecutter        networkx            string
# _codecs_cn          copy                nltk                stringprep
# _codecs_hk          copyreg             nntplib             struct
# _codecs_iso2022     crypt               nose                subprocess
# _codecs_jp          cryptography        notebook            sunau
# _codecs_kr          csv                 nt                  symbol
# _codecs_tw          ctypes              ntpath              sympy
# _collections        curl                ntsecuritycon       sympyprinting
# _collections_abc    curses              nturl2path          symtable
# _compat_pickle      cv2                 numba               sys
# _compression        cwp                 numbers             sysconfig
# _contextvars        cycler              numexpr             tables
# _csv                cython              numpy               tabnanny
# _ctypes             cythonmagic         numpydoc            tarfile
# _ctypes_test        cytoolz             oauthlib            tbb
# _daal4py            daal4py             odbc                tblib
# _datetime           dask                olefile             telnetlib
# _decimal            dataclasses         onedal              tempfile
# _distutils_hack     datetime            opcode              tensorboard
# _elementtree        dateutil            openpyxl            tensorboard_data_server
# _functools          dbi                 operator            tensorboard_plugin_wit
# _hashlib            dbm                 opt_einsum          tensorflow
# _heapq              dde                 optparse            tensorflow_estimator
# _imp                debugpy             os                  tensorflow_io_gcs_filesystem
# _io                 decimal             packaging           termcolor
# _json               decorator           pandas              terminado
# _locale             defusedxml          pandocfilters       test
# _lsprof             diff_match_patch    paramiko            test_pycosat
# _lzma               difflib             parser              testpath
# _markupbase         dis                 parso               tests
# _md5                distlib             partd               text_unidecode
# _msi                distributed         past                textdistance
# _multibytecodec     distutils           pasta               textwrap
# _multiprocessing    doctest             path                this
# _nsis               docutils            pathlib             threading
# _onedal4py_host     email               pathlib2            threadpoolctl
# _opcode             encodings           pathspec            three_merge
# _operator           ensurepip           patsy               tifffile
# _osx_support        entrypoints         pdb                 time
# _overlapped         enum                pep8                timeit
# _peg_parser         erfa                perfmon             timer
# _pickle             errno               pexpect             tinycss
# _py_abc             et_xmlfile          pickle              tkinter
# _pydecimal          fastcache           pickleshare         tlz
# _pyio               faulthandler        pickletools         token
# _pyrsistent_version filecmp             pip                 tokenize
# _pytest             fileinput           pipes               toml
# _queue              filelock            pkg_resources       toolz
# _random             flake8              pkginfo             tornado
# _sha1               flask               pkgutil             tqdm
# _sha256             flatbuffers         platform            trace
# _sha3               fnmatch             platformdirs        traceback
# _sha512             fontTools           plistlib            tracemalloc
# _signal             formatter           pluggy              traitlets
# _sitebuiltins       fractions           ply                 tty
# _socket             fsspec              poplib              turtle
# _sqlite3            ftplib              posixpath           turtledemo
# _sre                functools           poyo                typed_ast
# _ssl                future              pprint              types
# _stat               gast                profile             typing
# _statistics         gc                  prometheus_client   typing_extensions
# _string             genericpath         prompt_toolkit      ujson
# _strptime           getopt              pstats              unicodecsv
# _struct             getpass             psutil              unicodedata
# _symtable           gettext             pty                 unidecode
# _system_path        gevent              ptyprocess          unittest
# _testbuffer         glob                pvectorc            urllib
# _testcapi           glob2               py                  urllib3
# _testconsole        google_auth_oauthlib py_compile          uu
# _testimportmultiple graphlib            pyasn1              uuid
# _testinternalcapi   greenlet            pyasn1_modules      venv
# _testmultiphase     grpc                pyclbr              virtualenv
# _thread             gzip                pycodestyle         warnings
# _threading_local    h5py                pycosat             watchdog
# _tkinter            hashlib             pycparser           wave
# _tracemalloc        heapdict            pycurl              wcwidth
# _uuid               heapq               pydoc               weakref
# _warnings           hmac                pydoc_data          webbrowser
# _weakref            html                pydocstyle          webencodings
# _weakrefset         html5lib            pyexpat             werkzeug
# _win32sysloader     http                pyflakes            wheel
# _winapi             idlelib             pygments            whichcraft
# _winxptheme         idna                pylab               widgetsnbextension
# _xxsubinterpreters  imagecodecs         pylint              win2kras
# _yaml               imageio             pyls_spyder         win32api
# _zoneinfo           imagesize           pylsp               win32clipboard
# abc                 imaplib             pylsp_black         win32com
# absl                imghdr              pylsp_jsonrpc       win32con
# adodbapi            imp                 pyodbc              win32console
# afxres              importlib           pyparsing           win32cred
# aifc                importlib_metadata  pyreadline          win32crypt
# alabaster           inflection          pyrsistent          win32cryptcon
# anaconda_navigator  iniconfig           pytest              win32ctypes
# anaconda_project    inspect             pythoncom           win32event
# antigravity         intervaltree        pytz                win32evtlog
# anyio               io                  pywin               win32evtlogutil
# appdirs             ipaddress           pywin32_bootstrap   win32file
# argh                ipykernel           pywin32_testutil    win32gui
# argon2              ipykernel_launcher  pywintypes          win32gui_struct
# argparse            ipython_genutils    pywt                win32help
# array               ipywidgets          pyximport           win32inet
# arrow               isapi               qdarkstyle          win32inetcon
# asn1crypto          isort               qstylizer           win32job
# ast                 isympy              qtawesome           win32lz
# astroid             itertools           qtconsole           win32net
# astropy             itsdangerous        qtpy                win32netcon
# astunparse          jdcal               queue               win32pdh
# async_generator     jedi                quopri              win32pdhquery
# asynchat            jinja2              random              win32pdhutil
# asyncio             jinja2_time         rasutil             win32pipe
# asyncore            joblib              re                  win32print
# atexit              json                readline            win32process
# atomicwrites        json5               regcheck            win32profile
# attr                jsonschema          regex               win32ras
# audioop             jupyter             regutil             win32rcparser
# autopep8            jupyter_client      repo_cli            win32security
# autoreload          jupyter_console     reprlib             win32service
# babel               jupyter_core        requests            win32serviceutil
# backcall            jupyter_server      requests_oauthlib   win32timezone
# backports           jupyterlab          rlcompleter         win32trace
# base64              jupyterlab_pygments rmagic              win32traceutil
# bcrypt              jupyterlab_server   rope                win32transaction
# bdb                 jupyterlab_widgets  rsa                 win32ts
# binaryornot         jwt                 rtree               win32ui
# binascii            keras               ruamel_yaml         win32uiole
# binhex              keras_preprocessing run                 win32verstamp
# binstar_client      keyring             runpy               win32wnet
# bisect              keyword             sched               win_inet_pton
# bitarray            kiwisolver          scipy               win_unicode_console
# bkcharts            lazy_object_proxy   scripts             wincertstore
# black               lib2to3             seaborn             winerror
# blackd              libarchive          secrets             winioctlcon
# bleach              libfuturize         select              winnt
# blib2to3            libpasteurize       selectors           winperf
# bokeh               lief                send2trash          winpty
# boto                linecache           servicemanager      winreg
# bottleneck          llvmlite            setuptools          winsound
# brotli              locale              shelve              winxpgui
# bs4                 locket              shlex               winxptheme
# builtins            logging             shutil              wrapt
# bz2                 lxml                signal              wsgiref
# cProfile            lzma                simplegeneric       xdrlib
# cached_property     mailbox             singledispatch      xlrd
# cachetools          mailcap             sip                 xlsxwriter
# calendar            markdown            sipconfig           xlwings
# certifi             markupsafe          sipdistutils        xlwt
# cffi                marshal             site                xml
# cgi                 math                six                 xmlrpc
# cgitb               matplotlib          skimage             xmltodict
# chardet             matplotlib_inline   sklearn             xxsubtype
# charset_normalizer  mccabe              sklearnex           yaml
# chunk               menuinst            slugify             yapf
# clang               mimetypes           smtpd               yapftests
# click               mistune             smtplib             zict
# cloudpickle         mkl                 sndhdr              zipapp
# clyent              mkl_fft             sniffio             zipfile
# cmath               mkl_random          snowballstemmer     zipimport
# cmd                 mmap                socket              zipp
# code                mmapfile            socketserver        zlib
# codecs              mmsystem            socks               zmq
# codeop              mock                sockshandler        zoneinfo
# collections         modulefinder        sortedcollections   zope
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
